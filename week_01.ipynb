# %%
def average(scores):
    return sum(scores) / len(scores)
def add_average_to_students(students):
    for student in students:
        student["average"] = average(student["scores"])
def top_student(students):
    best_student = students[0]

    for student in students:
        if student["average"] > best_student["average"]:
            best_student = student

    return best_student["name"]
def passing_students(students, threshold=60):
    passed = []

    for student in students:
        if student["average"] >= threshold:
            passed.append(student["name"])

    return passed
def class_average(students):
    b = 0

    for student in students:
        b = b + student["average"]

    return b / len(students)
def print_report(students):
    for student in students:
        if student["average"] >= 60:
            status = "Pass"
        else:
            status = "Fail"

        print(f'{student["name"]}: {student["average"]} ({status})')
def most_consistent_student(students):
    pass
students = [
    {"name": "Sara", "scores": [82, 91, 76]},
    {"name": "Ali", "scores": [65, 70, 72]},
    {"name": "Niloofar", "scores": [95, 89, 92]},
    {"name": "Reza", "scores": [40, 45, 50]},
    {"name": "Maryam", "scores": [50, 55, 57]},
]
add_average_to_students(students)

print_report(students)

print()
print("Class average:", round(class_average(students), 1))
print("Top student:", top_student(students))
print("Passing students:", passing_students(students))
# Out:
# Sara: 83.0 (Pass)
# Ali: 69.0 (Pass)
# Niloofar: 92.0 (Pass)
# Reza: 45.0 (Fail)
# Maryam: 54.0 (Fail)
#
# Class average: 68.6
# Top student: Niloofar
# Passing students: ['Sara', 'Ali', 'Niloofar']
